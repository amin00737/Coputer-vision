# %%
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import  Dropout
from keras.layers import Layer
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score
from keras.applications.vgg16 import VGG16 
import os
from keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten,BatchNormalization
import copy
import sys
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
tf.__version__
# Out:
# '2.10.1'

# %%
target = []
data = []
dir='D:\\A.document\\A.opencv\\projects\\apple_garden\\Dataset'
#dir_test='D:\\A.document\\A.opencv\\projects\\apple_garden\\\Dataset_test'
#Categories = ['1','2','3','4']
Categories = ['1','3','4']

# %%
for i in Categories:
  print("Category is:",i,"\tLabel encoded as:",Categories.index(i))
  target_class = Categories.index(i)
  path = os.path.join(dir,i)
  for img in os.listdir(path):
    img_array = cv2.imread(os.path.join(path,img))
    img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    img_resized =cv2.resize(img_array,(124,124))
    data.append(img_resized)
    target.append(target_class)

data = np.array(data)
target = np.array(target)

print('end')
# Out:
# Category is: 1 	Label encoded as: 0
# Category is: 3 	Label encoded as: 1
# Category is: 4 	Label encoded as: 2
# end

# %%
RGB_img=data[1520]
plt.imshow(RGB_img)
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(data,target,test_size=0.025)#test_size=0.03

X_test.shape
# Out:
# (60, 124, 124, 3)

# %%
#y_test

# %%
X_train.shape
# Out:
# (2339, 124, 124, 3)

# %%
class_number = 3

# %%
f, ax = plt.subplots(1, class_number, figsize=(20,20))

for i in range(0, class_number):
    apple_sample = X_train[y_train == i][0]
    #apple_sample =cv2.cvtColor(apple_sample,cv2.COLOR_BGR2RGB)
    ax[i].imshow(apple_sample)
    ax[i].set_title("Label: {}".format(i), fontsize=20)

# %%
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

print(X_train.shape[0], "train")
print(X_test.shape[0], "test")


y_train = keras.utils.to_categorical(y_train, class_number)
y_test = keras.utils.to_categorical(y_test, class_number)
# Out:
# 2339 train
# 60 test

# %%
fa=keras.initializers.VarianceScaling(scale=1.0, mode='fan_avg', distribution='normal', seed=0) 
initializer = tf.keras.initializers.GlorotNormal(seed=0)
model1 = keras.Sequential(
    [
      keras.layers.Conv2D(32,(3,3), activation='elu',padding='same', input_shape = (124,124,3)), 
      keras.layers.BatchNormalization(),  
      keras.layers.Conv2D(32,(3,3), activation='elu', padding = 'same', kernel_initializer = fa),
      keras.layers.BatchNormalization(),  
      keras.layers.MaxPooling2D((2,2)),
      keras.layers.Conv2D(64,(3,3), activation='elu', padding = 'same',kernel_initializer = fa),
      keras.layers.BatchNormalization(),  
      keras.layers.Conv2D(64,(3,3), activation='elu', padding = 'same',kernel_initializer = fa),
      keras.layers.BatchNormalization(),  
      keras.layers.MaxPooling2D((2,2)),
      keras.layers.Conv2D(128,(3,3), activation='elu', padding = 'same',kernel_initializer = fa),
      keras.layers.BatchNormalization(),  
      keras.layers.MaxPooling2D((2,2)),  
      keras.layers.Conv2D(256,(3,3), activation='elu', padding = 'same',kernel_initializer = fa),
      keras.layers.BatchNormalization(),  
      keras.layers.MaxPooling2D((2,2)),
      keras.layers.Flatten(),
      keras.layers.Dense(64,activation = 'elu', kernel_initializer = "he_uniform"),
      keras.layers.BatchNormalization(),
      keras.layers.Dense(64,activation = 'elu', kernel_initializer = "he_uniform"),
      keras.layers.BatchNormalization(),  
      keras.layers.Dense(3, activation= 'softmax')
    ]
)

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 124, 124, 32)      896
#
#  batch_normalization (BatchN  (None, 124, 124, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 124, 124, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 124, 124, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 62, 62, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 62, 62, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 62, 62, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 62, 62, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 31, 31, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 31, 31, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 256)       295168
#
#  batch_normalization_5 (Batc  (None, 15, 15, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 64)                802880
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,244,643
# Trainable params: 1,243,235
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
sgd=keras.optimizers.SGD(clipvalue=0.1)
adagrad_1=keras.optimizers.Adagrad(learning_rate=0.1)
adam=keras.optimizers.Adam(learning_rate=0.01)
Nadam=keras.optimizers.Nadam(learning_rate=0.01)
Adamax1=keras.optimizers.Adamax(learning_rate=0.01)

# %%
model1.compile(loss="categorical_crossentropy",
             optimizer=Adamax1,metrics=["accuracy"])

# %%
history = model1.fit(X_train, y_train,batch_size=12,epochs=3000,validation_split=0.025,
                        callbacks=[keras.callbacks.EarlyStopping(patience=35,monitor='val_accuracy',restore_best_weights=True),
                           keras.callbacks.ModelCheckpoint(filepath='Apple_Amin1.h5',monitor='val_accuracy',save_best_only=True)])
# Out:
# Epoch 1/3000
# 190/190 [==============================] - 13s 39ms/step - loss: 0.4893 - accuracy: 0.7969 - val_loss: 1.6064 - val_accuracy: 0.3559
# Epoch 2/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.4051 - accuracy: 0.8272 - val_loss: 0.3373 - val_accuracy: 0.8644
# Epoch 3/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.3637 - accuracy: 0.8583 - val_loss: 0.2960 - val_accuracy: 0.8814
# Epoch 4/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.3650 - accuracy: 0.8500 - val_loss: 0.4320 - val_accuracy: 0.8136
# Epoch 5/3000
# 190/190 [==============================] - 7s 38ms/step - loss: 0.3329 - accuracy: 0.8689 - val_loss: 0.1816 - val_accuracy: 0.9492
# Epoch 6/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.3139 - accuracy: 0.8772 - val_loss: 0.3752 - val_accuracy: 0.8475
# Epoch 7/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2895 - accuracy: 0.8873 - val_loss: 0.2588 - val_accuracy: 0.9153
# Epoch 8/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2757 - accuracy: 0.8961 - val_loss: 0.2828 - val_accuracy: 0.8644
# Epoch 9/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2808 - accuracy: 0.8925 - val_loss: 0.2551 - val_accuracy: 0.8983
# Epoch 10/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2634 - accuracy: 0.8982 - val_loss: 0.3267 - val_accuracy: 0.8983
# Epoch 11/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2588 - accuracy: 0.9088 - val_loss: 0.2260 - val_accuracy: 0.9322
# Epoch 12/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2550 - accuracy: 0.9057 - val_loss: 0.2722 - val_accuracy: 0.9153
# Epoch 13/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2196 - accuracy: 0.9232 - val_loss: 0.2162 - val_accuracy: 0.9322
# Epoch 14/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2034 - accuracy: 0.9276 - val_loss: 0.2901 - val_accuracy: 0.9153
# Epoch 15/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1993 - accuracy: 0.9289 - val_loss: 0.3802 - val_accuracy: 0.8475
# Epoch 16/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.2023 - accuracy: 0.9219 - val_loss: 0.2587 - val_accuracy: 0.9322
# Epoch 17/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1554 - accuracy: 0.9399 - val_loss: 0.5309 - val_accuracy: 0.8305
# Epoch 18/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1944 - accuracy: 0.9342 - val_loss: 0.3535 - val_accuracy: 0.8475
# Epoch 19/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1532 - accuracy: 0.9456 - val_loss: 0.1271 - val_accuracy: 0.9322
# Epoch 20/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1434 - accuracy: 0.9500 - val_loss: 0.3087 - val_accuracy: 0.8814
# Epoch 21/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1133 - accuracy: 0.9601 - val_loss: 0.1906 - val_accuracy: 0.9322
# Epoch 22/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1466 - accuracy: 0.9500 - val_loss: 0.2991 - val_accuracy: 0.8305
# Epoch 23/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1355 - accuracy: 0.9522 - val_loss: 0.3043 - val_accuracy: 0.8814
# Epoch 24/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1081 - accuracy: 0.9662 - val_loss: 0.1719 - val_accuracy: 0.9322
# Epoch 25/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0978 - accuracy: 0.9658 - val_loss: 0.1423 - val_accuracy: 0.9661
# Epoch 26/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.1080 - accuracy: 0.9632 - val_loss: 0.4023 - val_accuracy: 0.9322
# Epoch 27/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0710 - accuracy: 0.9781 - val_loss: 0.2155 - val_accuracy: 0.9661
# Epoch 28/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0746 - accuracy: 0.9776 - val_loss: 0.3416 - val_accuracy: 0.9153
# Epoch 29/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0651 - accuracy: 0.9772 - val_loss: 0.3074 - val_accuracy: 0.9322
# Epoch 30/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0590 - accuracy: 0.9794 - val_loss: 0.3586 - val_accuracy: 0.9492
# Epoch 31/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0660 - accuracy: 0.9772 - val_loss: 0.1860 - val_accuracy: 0.9661
# Epoch 32/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0647 - accuracy: 0.9781 - val_loss: 0.2470 - val_accuracy: 0.9492
# Epoch 33/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0517 - accuracy: 0.9825 - val_loss: 0.1879 - val_accuracy: 0.9661
# Epoch 34/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0450 - accuracy: 0.9890 - val_loss: 0.5108 - val_accuracy: 0.8644
# Epoch 35/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0939 - accuracy: 0.9732 - val_loss: 0.3005 - val_accuracy: 0.9153
# Epoch 36/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0576 - accuracy: 0.9807 - val_loss: 0.2156 - val_accuracy: 0.9492
# Epoch 37/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0480 - accuracy: 0.9851 - val_loss: 0.2781 - val_accuracy: 0.9322
# Epoch 38/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0315 - accuracy: 0.9882 - val_loss: 0.2040 - val_accuracy: 0.9322
# Epoch 39/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0532 - accuracy: 0.9829 - val_loss: 0.1625 - val_accuracy: 0.9661
# Epoch 40/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0413 - accuracy: 0.9882 - val_loss: 0.3158 - val_accuracy: 0.9153
# Epoch 41/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0411 - accuracy: 0.9864 - val_loss: 0.3160 - val_accuracy: 0.9492
# Epoch 42/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0347 - accuracy: 0.9860 - val_loss: 0.2335 - val_accuracy: 0.9153
# Epoch 43/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0354 - accuracy: 0.9912 - val_loss: 0.2329 - val_accuracy: 0.9322
# Epoch 44/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0409 - accuracy: 0.9842 - val_loss: 0.2417 - val_accuracy: 0.9661
# Epoch 45/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0677 - accuracy: 0.9776 - val_loss: 0.2636 - val_accuracy: 0.9322
# Epoch 46/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0500 - accuracy: 0.9842 - val_loss: 0.3003 - val_accuracy: 0.9322
# Epoch 47/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0350 - accuracy: 0.9899 - val_loss: 0.2462 - val_accuracy: 0.9492
# Epoch 48/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0352 - accuracy: 0.9917 - val_loss: 0.1795 - val_accuracy: 0.9661
# Epoch 49/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0588 - accuracy: 0.9785 - val_loss: 0.2278 - val_accuracy: 0.9322
# Epoch 50/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0232 - accuracy: 0.9952 - val_loss: 0.2335 - val_accuracy: 0.9322
# Epoch 51/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0327 - accuracy: 0.9890 - val_loss: 0.2679 - val_accuracy: 0.9661
# Epoch 52/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0324 - accuracy: 0.9930 - val_loss: 0.1940 - val_accuracy: 0.9492
# Epoch 53/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0411 - accuracy: 0.9886 - val_loss: 0.1864 - val_accuracy: 0.9492
# Epoch 54/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0193 - accuracy: 0.9952 - val_loss: 0.1979 - val_accuracy: 0.9492
# Epoch 55/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0293 - accuracy: 0.9934 - val_loss: 0.2321 - val_accuracy: 0.9492
# Epoch 56/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0391 - accuracy: 0.9886 - val_loss: 0.1906 - val_accuracy: 0.9661
# Epoch 57/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 0.3024 - val_accuracy: 0.9153
# Epoch 58/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.2230 - val_accuracy: 0.9492
# Epoch 59/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.2945 - val_accuracy: 0.9492
# Epoch 60/3000
# 190/190 [==============================] - 7s 37ms/step - loss: 0.0239 - accuracy: 0.9930 - val_loss: 0.3518 - val_accuracy: 0.9153

# %%
fig,ax = plt.subplots(figsize=(12,5))
ax=plt.plot(history.history["loss"],label="loss")
ax=plt.plot(history.history["accuracy"],label="accuracy")
ax=plt.plot(history.history["val_loss"],label="val_loss")
ax=plt.plot(history.history["val_accuracy"],label="val_accuracy")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
model1.evaluate(X_test,y_test,verbose=1)
# Out:
# 2/2 [==============================] - 1s 146ms/step - loss: 0.0564 - accuracy: 0.9833
# [0.05643507465720177, 0.9833333492279053]

# %%
model2=keras.models.load_model("Apple_Amin1.h5")
y_pred_classes1 = model2.predict(X_test)
y_pred_classes1 = np.argmax(y_pred_classes1, axis=1)
print(y_pred_classes1)
# Out:
# 2/2 [==============================] - 0s 268ms/step
# [0 2 2 1 1 2 2 2 0 0 2 2 2 0 0 0 1 0 0 0 2 1 1 1 1 0 1 0 0 2 1 0 0 0 0 2 0
#  2 2 0 1 2 2 2 0 2 0 2 0 2 2 1 2 1 0 2 2 0 0 0]

# %%
y_test = np.argmax(y_test, axis=1)
print(y_test)
# Out:
# [1 2 2 1 1 2 2 2 0 0 2 2 2 0 0 0 1 0 0 0 2 1 1 1 1 0 1 0 0 2 1 0 0 0 0 2 0
#  2 2 0 1 2 2 2 0 2 0 2 0 2 2 1 2 1 0 2 2 0 0 0]

# %%
model2.evaluate(X_test,y_test,verbose=1)
# Out:
# 2/2 [==============================] - 1s 31ms/step - loss: 0.0564 - accuracy: 0.9833
# [0.05643507465720177, 0.9833333492279053]

# %%
y_test1 = keras.utils.to_categorical(y_test, class_number)
random_idx = np.random.choice(len(X_test))
print(random_idx)
x_sample = X_test[random_idx]
y_true = np.argmax(y_test1, axis=1)
y_sample_true = y_true[random_idx]
y_sample_pred_class = y_pred_classes1[random_idx]

plt.title("Predicted: {}, Real: {}".format(y_sample_pred_class, y_sample_true), fontsize=16)
plt.imshow(x_sample.reshape(124,124,3), cmap='gray')
# Out:
# 46

# %%
model2=keras.models.load_model("Apple_Amin1.h5")
img3_1 = cv2.imread('D:\\A.document\\A.opencv\\projects\\apple_garden\\Dataset_test\\4\\aug_101_2454.png')
img3_1=cv2.cvtColor(img3_1, cv2.COLOR_BGR2RGB)
plt.imshow(img3_1)

img3=copy.copy(img3_1)

img3=cv2.resize(img3,(124,124))
print(img3.shape)

img = img3.reshape(1, 124,124, 3)
print(img.shape)
img = img.astype('float32')
img = img / 255.0


y_pred1 = model2.predict(img)
y_pred1 = np.argmax(y_pred1, axis=1)
print(y_pred1)
# Out:
# (124, 124, 3)
# (1, 124, 124, 3)
# 1/1 [==============================] - 0s 424ms/step
# [2]

# %%
y_test11 = np.argmax(y_test1, axis=1)
confusion_matrix1=confusion_matrix(y_test11, y_pred_classes1)
confusion_matrix1
# Out:
# array([[24,  0,  0],
#        [ 1, 12,  0],
#        [ 0,  0, 23]], dtype=int64)

# %%
sns.set(font_scale=1.4)
plt.rcParams["font.family"] = "Times New Roman"
plt.figure(figsize=(10,10))

ax = sns.heatmap(confusion_matrix1,annot=True,fmt="0.2f",linewidth=.5, annot_kws={'size': 15})
ax.tick_params(labelsize=15)
